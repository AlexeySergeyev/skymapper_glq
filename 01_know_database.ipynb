# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tabula
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
df_known = pd.DataFrame(columns=['Name', 'ra', 'dec', 'n'])

# %% [markdown]
# # Lemmon database

# %%
df_lemon = pd.read_csv('data/known_gls.csv')
df_lemon
# Out:
#              RA        DEC            Name  z_qso    z_lens  separation  \
# 0      2.834350  -8.764300      J0011-0845    1.7         -        1.89
# 1      3.348077  51.318300      J0013+5119   2.63         -        2.92
# 2      7.093690   6.531700    PSJ0028+0631   1.06         -        2.81
# 3      7.563600 -15.417700    PSJ0030-1525   3.36  measured        1.78
# 4     11.946594  25.241100      J0047+2514   1.20         -        1.73
# ..          ...        ...             ...    ...       ...         ...
# 215  353.080500 -18.868500    PSJ2332-1852   1.49         -        1.97
# 216  355.799750  -0.842860  ULASJ2343-0050  0.787       0.3        1.32
# 217  356.070600 -30.940560   WISE2344-3056  1.298      1.30        2.18
# 218  357.491900 -45.314700   DESJ2349-4518   2.89         -        2.11
# 219  357.531433  36.909587      J2350+3654  2.085         -        3.31
#
#      N_images      W1      W2   smss
# 0           2  15.190  14.455  False
# 1           2  14.677  13.920   True
# 2           2  14.160  13.363  False
# 3           4  14.312  13.761  False
# 4           2  14.942  14.269   True
# ..        ...     ...     ...    ...
# 215         2  14.744  13.787  False
# 216         2  14.647  13.686  False
# 217         4  14.758  13.889  False
# 218         2  14.939  14.322  False
# 219         2  14.403  13.869   True
#
# [220 rows x 10 columns]

# %%
df_known['Name'] = df_lemon['Name']
df_known['ra'] = df_lemon['RA']
df_known['dec'] = df_lemon['DEC'].astype(float)
df_known['n'] = df_lemon['N_images']
df_known
# Out:
#                Name          ra        dec  n
# 0        J0011-0845    2.834350  -8.764300  2
# 1        J0013+5119    3.348077  51.318300  2
# 2      PSJ0028+0631    7.093690   6.531700  2
# 3      PSJ0030-1525    7.563600 -15.417700  4
# 4        J0047+2514   11.946594  25.241100  2
# ..              ...         ...        ... ..
# 215    PSJ2332-1852  353.080500 -18.868500  2
# 216  ULASJ2343-0050  355.799750  -0.842860  2
# 217   WISE2344-3056  356.070600 -30.940560  4
# 218   DESJ2349-4518  357.491900 -45.314700  2
# 219      J2350+3654  357.531433  36.909587  2
#
# [220 rows x 4 columns]

# %%
df_known.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    220 non-null    object
#  1   ra      220 non-null    float64
#  2   dec     220 non-null    float64
#  3   n       220 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 7.0+ KB

# %%
"""
java -jar .venv/lib/python3.12/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar -p 14 -a 100,10,410,600 -o ./data/strides_quads.csv "/Users/alexeysergeyev/Zotero/storage/GYY7NDJT/Schmidt et al. - 2023 - STRIDES automated uniform models for 30 quadruply imaged quasars.pdf"
"""
df_strides = pd.read_csv('data/strides_quads.csv', header=None)

df_strides.replace(' ', '', regex=True, inplace=True)
# Replace non-standard minus sign with standard minus sign
df_strides[2] = df_strides[2].astype('str').str.replace('−', '-')

# Convert the column to float
df_strides[1] = df_strides[1].astype(float)
df_strides[2] = df_strides[2].astype(float)
# df_strides[2].astype('str').replace('−', '-', regex=True, inplace=True)
df_strides
# Out:
#                  0           1          2       3       4       5       6   \
# 0        J0029−3814    7.419298 -38.240600  −0.134  −0.155   1.156  −0.513
# 1      PSJ0030−1525    7.563492 -15.417800  −0.098   0.020   0.746  −0.908
# 2     DESJ0053−2012   13.435033 -20.209147  −0.422   0.429  −0.529   1.036
# 3      PSJ0147+4630   26.792372  46.511872  −0.145  −1.137  −0.317  −2.296
# 4       WG0214−2105   33.568175 -21.093137   0.071  −0.015   0.556  −0.868
# 5    SDSSJ0248+1913   42.203067  19.225228   0.105   0.071   0.451  −0.748
# 6    WISEJ0259−1635   44.928533 -16.595370   0.058  −0.039   0.035  −0.730
# 7        J0343−2828   55.797650 -28.477948  −0.869   0.894  −1.251   1.352
# 8     DESJ0405−3308   61.498960 -33.147410  −0.014  −0.045   0.691  −0.279
# 9     DESJ0420−4037   65.194823 -40.624087   0.113  −0.001   0.821  −0.579
# 10    DESJ0530−3730   82.654075 -37.503113   0.325  −0.325   0.597  −0.517
# 11     PSJ0630−1201   97.537708 -12.022081  −0.502   0.275  −1.370   1.157
# 12       J0659+1629  104.766545  16.485908   0.390  −0.066   2.192  −0.928
# 13       J0818−2613  124.617817 -26.223740  −0.882   1.184  −2.488  −2.982
# 14    W2MJ1042+1641  160.592005  16.687614  −0.052   0.034  −0.858   0.687
# 15       J1131−4419  172.750079 -44.333469  −0.012   0.050   0.072  −0.742
# 16      2M1134−2103  173.668952 -21.056299  −0.154   0.174   1.326   1.150
# 17   SDSSJ1251+2935  192.781367  29.594673   0.185  −0.050  −0.885   0.278
# 18      2M1310−1714  197.583583 -17.249381  −0.191   0.522  −1.093   2.656
# 19   SDSSJ1330+1810  202.577718  18.175763   0.170   0.068   0.629   0.700
# 20   SDSSJ1433+6007  218.345150  60.120839   0.451  −0.218   1.558  −0.338
# 21       J1537−3010  234.355668 -30.171336   0.095  −0.030   1.491  −0.815
# 22     PSJ1606−2333  241.500980 -23.556122   0.035   0.025   0.852   0.414
# 23       J1721+8842  260.432958  88.705847  −0.287   0.261  −1.694  −0.094
# 24       J1817+2729  274.378603  27.494383   0.096   0.105   0.655  −0.732
# 25    DESJ2038−4008  309.511333 -40.137050   0.117   0.074   0.819   0.938
# 26      WG2100−4452  315.062075 -44.868438  −0.078   0.072  −0.286   1.128
# 27       J2145+6345  326.271094  63.761447  −0.174   0.394  −0.955  −0.650
# 28       J2205−3727  331.434422 -37.450361  −0.046   0.088   0.859   0.189
# 29  ATLASJ2344−3056  356.070733 -30.940611   0.055  −0.115  −0.431   0.073
#
#         7       8       9       10      11      12
# 0   −0.592  −0.490  −0.975   0.071  −0.321   0.384
# 1   −0.868   0.002   0.778   0.887   1.005   0.608
# 2    1.414   0.012   0.691  −0.731  −1.424  −1.111
# 3   −1.218   0.836   0.029   0.936   1.191   0.526
# 4   −0.706  −0.136  −0.260   0.790   0.633   0.517
# 5   −0.549  −0.135  −0.404   0.699   0.503   0.661
# 6   −0.727   0.216   0.434   0.537   0.752  −0.342
# 7    1.959   1.349   1.364  −0.746  −1.329  −1.952
# 8   −0.374  −0.605  −0.529   0.416   0.349   0.556
# 9   −0.586  −0.349  −0.339   0.675   0.287   0.796
# 10  −0.384  −0.237  −0.143   0.243  −0.018   0.311
# 11   1.151   0.416   0.822  −0.704   0.302  −1.268
# 12  −2.481  −1.265   1.205   1.953   2.274   0.974
# 13  −2.042   2.603   2.010   1.366   1.854   0.695
# 14   0.694   0.111   0.526  −0.468  −0.087  −0.803
# 15  −0.881   0.349   0.411   0.793   0.754   0.446
# 16   0.593  −0.609  −1.356  −1.384  −0.660   0.765
# 17   0.829   0.286   0.895  −0.304   0.533  −0.678
# 18   2.790   0.165   1.508  −2.447  −2.295  −2.222
# 19   0.384  −0.902  −0.023  −0.910  −0.860   0.256
# 20  −0.486  −1.913  −1.243  −0.288  −0.480   1.842
# 21  −0.471  −1.126  −1.352   0.822   0.772   0.970
# 22   0.065  −0.490  −0.765  −0.173  −0.272   0.567
# 23   0.312   2.378   1.589   0.965   1.242  −1.361
# 24  −0.692  −0.256  −0.607   0.553   0.671   0.709
# 25   0.945  −1.141  −0.572  −1.112  −1.367   0.569
# 26   1.318  −0.401  −0.703  −1.083  −1.125  −0.749
# 27  −0.487   1.020   0.890   0.280   0.571  −0.298
# 28  −0.342  −0.536  −0.780   0.066  −0.491   0.624
# 29   0.150   0.425   0.442  −0.245  −0.191  −0.583

# %%
coords_known = SkyCoord(ra=df_known['ra'], dec=df_known['dec'], unit=(u.deg, u.deg))
coords_strides = SkyCoord(ra=df_strides[1], dec=df_strides[2], unit=(u.deg, u.deg))
idx, d2d, _, = coords_strides.match_to_catalog_sky(coords_known)
df_strides['sep'] = d2d.to(u.arcsec).value
cond = df_strides['sep'] > 10
df_add = df_strides.loc[cond, [0, 1, 2]]
# df_add['n'] = 4 * np.ones(df_add.shape[0])
df_add[1] = df_add[1].astype(float)
df_add[2] = df_add[2].astype(float)
df_add
# Out:
#                 0           1          2
# 0      J0029−3814    7.419298 -38.240600
# 7      J0343−2828   55.797650 -28.477948
# 9   DESJ0420−4037   65.194823 -40.624087
# 12     J0659+1629  104.766545  16.485908
# 13     J0818−2613  124.617817 -26.223740
# 28     J2205−3727  331.434422 -37.450361

# %%
df_known = pd.concat([df_known, df_add[[0, 1, 2]].rename(columns={0: 'Name', 1: 'ra', 2: 'dec'})], ignore_index=True)
df_known
# Out:
#               Name          ra        dec    n
# 0       J0011-0845    2.834350  -8.764300  2.0
# 1       J0013+5119    3.348077  51.318300  2.0
# 2     PSJ0028+0631    7.093690   6.531700  2.0
# 3     PSJ0030-1525    7.563600 -15.417700  4.0
# 4       J0047+2514   11.946594  25.241100  2.0
# ..             ...         ...        ...  ...
# 221     J0343−2828   55.797650 -28.477948  NaN
# 222  DESJ0420−4037   65.194823 -40.624087  NaN
# 223     J0659+1629  104.766545  16.485908  NaN
# 224     J0818−2613  124.617817 -26.223740  NaN
# 225     J2205−3727  331.434422 -37.450361  NaN
#
# [226 rows x 4 columns]

# %%
df_known.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    226 non-null    object
#  1   ra      226 non-null    float64
#  2   dec     226 non-null    float64
#  3   n       220 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # 150 candidates

# %%
"""
java -jar .venv/lib/python3.12/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar -p 4-5 -a 130,40,800,600 -o ./data/lemon150_1-2.csv "/Users/alexeysergeyev/Zotero/storage/BCFE69ZR/Lemon et al. - 2022 - Gravitationally lensed quasars in Gaia -- IV. 150 new lenses, quasar pairs, and projected quasars.pdf"
"""
"""
java -jar .venv/lib/python3.12/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar -p 6 -a 120,40,660,600 -o ./data/lemon150_3.csv "/Users/alexeysergeyev/Zotero/storage/BCFE69ZR/Lemon et al. - 2022 - Gravitationally lensed quasars in Gaia -- IV. 150 new lenses, quasar pairs, and projected quasars.pdf"
"""
# Out:
# '\njava -jar .venv/lib/python3.12/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar -p 6 -a 120,40,660,600 -o ./data/lemon150_3.csv "/Users/alexeysergeyev/Zotero/storage/BCFE69ZR/Lemon et al. - 2022 - Gravitationally lensed quasars in Gaia -- IV. 150 new lenses, quasar pairs, and projected quasars.pdf"\n'

# %%
df1 = pd.read_csv('data/lemon150_1-2.csv')
df2 = pd.read_csv('data/lemon150_3.csv')
df1.dropna(subset=['Name'], inplace=True)
df2.dropna(subset=['Name'], inplace=True)
df_lemon150 = pd.concat([df1, df2])
df_lemon150
# Out:
#           Name      R.A.     Dec. Selection        Gaia G  Sep. (′′)  \
# 0   J0021+1927    5.4936  19.4646    WD, MD  20.77, 19.96       2.89
# 1   J0027+0438    6.9580   4.6443    WD, MD  17.65, 20.18       1.92
# 2   J0029–0414    7.3861  -4.2472    WD, MD  19.27, 20.43       1.11
# 3   J0030–3358    7.6740 -33.9767        GP         20.89       2.03
# 4   J0032–4523    8.1130 -45.3884    WD, MD  20.57, 20.21       2.33
# ..         ...       ...      ...       ...           ...        ...
# 48  J2318+0250  349.5541   2.8411    WD, MD  19.59, 19.43       3.23
# 49  J2322+0916  350.6413   9.2796    WD, MD  20.51, 18.18       4.51
# 50  J2334+5036  353.5277  50.6114        WD  19.88, 19.18       2.13
# 51  J2341–1557  355.4664 -15.9501        WD  20.71, 20.06       1.02
# 52  J2355–4553  358.7761 -45.8931        WD  20.01, 20.69       2.20
#
#          PMSIG   Run                   Classification Gaia P.M. sig.
# 0   1.05, 2.74   NOT    projected QSOs, z=1.045, 1.09            NaN
# 1      0.56, —   NOT  projected QSOs, z=0.1935, 1.972            NaN
# 2      1.13, —  NTT3               z=0.518 QSO + star            NaN
# 3            —  NTT1        lens, z=1.58, zlens=0.715            NaN
# 4   0.12, 0.56  NTT3    projected QSOs, z=1.667, 1.74            NaN
# ..         ...   ...                              ...            ...
# 48         NaN   NOT    projected QSOs, z=1.83, 1.945     2.88, 0.78
# 49         NaN   NOT                 QSO pair, z=1.20     1.50, 1.37
# 50         NaN   NOT                            Stars     1.99, 5.49
# 51         NaN  NTT3                     NIQ, z=1.535        —, 0.85
# 52         NaN  NTT3                 QSO pair, z=2.85     1.67, 0.67
#
# [175 rows x 10 columns]

# %%
cond = df_lemon150['Classification'].str.contains('lens')
df_lens = df_lemon150[cond]
df_lens['Dec.'].astype('str').replace('−', '-', regex=True, inplace=True)
df_lens.loc[:, 'Name'] = df_lens['Name'].astype('str')
df_lens
# Out:
#           Name      R.A.     Dec. Selection        Gaia G  Sep. (′′)  \
# 3   J0030–3358    7.6740 -33.9767        GP         20.89       2.03
# 6   J0045–3937   11.3665 -39.6262        WD  19.70, 18.98       1.14
# 7   J0116+4052   19.1635  40.8811    WD, MD  19.84, 18.96       1.28
# 15  J0149–6532   27.2906 -65.5404        GP         20.58       2.74
# 16  J0152–2448   28.0797 -24.8105    WD, MD  20.12, 18.66       1.91
# ..         ...       ...      ...       ...           ...        ...
# 34  J2147–1340  326.9957 -13.6772        WD  19.85, 20.23       1.33
# 35  J2205+1019  331.4161  10.3307    WD, MD  18.53, 18.65       1.34
# 38  J2213–5926  333.3363 -59.4376        GP         20.83       2.59
# 43  J2308+3201  347.0777  32.0294        WD  20.31, 19.54       2.63
# 47  J2316+0610  349.1335   6.1804    WD, MD  20.05, 20.75       2.32
#
#          PMSIG           Run              Classification Gaia P.M. sig.
# 3            —          NTT1   lens, z=1.58, zlens=0.715            NaN
# 6   1.39, 0.60          NTT2                lens, z=1.85            NaN
# 7      —, 1.07           NOT                lens, z=1.85            NaN
# 15           —          NTT1  lens(?), z=0.944?, z=0.395            NaN
# 16  3.81, 2.05           NOT                lens, z=1.69            NaN
# ..         ...           ...                         ...            ...
# 34         NaN           NOT               lens, z=1.382        1.87, —
# 35         NaN           NOT                lens, z=1.78        —, 1.69
# 38         NaN  NTT3 (/NTT1)                lens, z=1.72              —
# 43         NaN           NOT                lens, z=2.30     1.41, 2.00
# 47         NaN           NOT               lens, z=1.955        1.18, —
#
# [79 rows x 10 columns]

# %%
df_lens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, 3 to 47
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            79 non-null     object
#  1   R.A.            79 non-null     float64
#  2   Dec.            79 non-null     float64
#  3   Selection       79 non-null     object
#  4   Gaia G          78 non-null     object
#  5   Sep. (′′)       79 non-null     float64
#  6   PMSIG           60 non-null     object
#  7   Run             79 non-null     object
#  8   Classification  79 non-null     object
#  9   Gaia P.M. sig.  18 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 6.8+ KB

# %%
coords_known = SkyCoord(ra=df_known['ra'], dec=df_known['dec'], unit=(u.deg, u.deg))
coords = SkyCoord(ra=df_lens['R.A.'], dec=df_lens['Dec.'], unit=(u.deg, u.deg))
idx, d2d, _, = coords.match_to_catalog_sky(coords_known)
df_lens.loc[:, 'sep'] = d2d.to(u.arcsec).value
cond = df_lens['sep'] > 10
df_add = df_lens[cond].reset_index(drop=True)
# df_add['n'] = 4
df_add
# Out:
# /var/folders/z7/xdmr6nzd7tbdjw0hjsyc05l00000gn/T/ipykernel_17730/3308132421.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_lens.loc[:, 'sep'] = d2d.to(u.arcsec).value
#           Name      R.A.     Dec. Selection        Gaia G  Sep. (′′)  \
# 0   J0030–3358    7.6740 -33.9767        GP         20.89       2.03
# 1   J0045–3937   11.3665 -39.6262        WD  19.70, 18.98       1.14
# 2   J0116+4052   19.1635  40.8811    WD, MD  19.84, 18.96       1.28
# 3   J0149–6532   27.2906 -65.5404        GP         20.58       2.74
# 4   J0152–2448   28.0797 -24.8105    WD, MD  20.12, 18.66       1.91
# ..         ...       ...      ...       ...           ...        ...
# 73  J2147–1340  326.9957 -13.6772        WD  19.85, 20.23       1.33
# 74  J2205+1019  331.4161  10.3307    WD, MD  18.53, 18.65       1.34
# 75  J2213–5926  333.3363 -59.4376        GP         20.83       2.59
# 76  J2308+3201  347.0777  32.0294        WD  20.31, 19.54       2.63
# 77  J2316+0610  349.1335   6.1804    WD, MD  20.05, 20.75       2.32
#
#          PMSIG           Run              Classification Gaia P.M. sig.  \
# 0            —          NTT1   lens, z=1.58, zlens=0.715            NaN
# 1   1.39, 0.60          NTT2                lens, z=1.85            NaN
# 2      —, 1.07           NOT                lens, z=1.85            NaN
# 3            —          NTT1  lens(?), z=0.944?, z=0.395            NaN
# 4   3.81, 2.05           NOT                lens, z=1.69            NaN
# ..         ...           ...                         ...            ...
# 73         NaN           NOT               lens, z=1.382        1.87, —
# 74         NaN           NOT                lens, z=1.78        —, 1.69
# 75         NaN  NTT3 (/NTT1)                lens, z=1.72              —
# 76         NaN           NOT                lens, z=2.30     1.41, 2.00
# 77         NaN           NOT               lens, z=1.955        1.18, —
#
#              sep
# 0   15367.883209
# 1   12125.450728
# 2   14740.080196
# 3   23380.560427
# 4   22581.117926
# ..           ...
# 73  46386.042648
# 74  33350.412477
# 75   8176.343098
# 76  18837.491854
# 77   5286.890779
#
# [78 rows x 11 columns]

# %%
df_known = pd.concat([df_known, df_add[['Name', 'R.A.', 'Dec.']].rename(columns={'R.A.': 'ra', 'Dec.': 'dec'})], ignore_index=True)
df_known
# Out:
#              Name          ra      dec    n
# 0      J0011-0845    2.834350  -8.7643  2.0
# 1      J0013+5119    3.348077  51.3183  2.0
# 2    PSJ0028+0631    7.093690   6.5317  2.0
# 3    PSJ0030-1525    7.563600 -15.4177  4.0
# 4      J0047+2514   11.946594  25.2411  2.0
# ..            ...         ...      ...  ...
# 299    J2147–1340  326.995700 -13.6772  NaN
# 300    J2205+1019  331.416100  10.3307  NaN
# 301    J2213–5926  333.336300 -59.4376  NaN
# 302    J2308+3201  347.077700  32.0294  NaN
# 303    J2316+0610  349.133500   6.1804  NaN
#
# [304 rows x 4 columns]

# %%
df_known.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    304 non-null    object
#  1   ra      304 non-null    float64
#  2   dec     304 non-null    float64
#  3   n       220 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 9.6+ KB

# %%
df_known.to_csv('data/my_gls.csv', index=False)

# %%
df_known = pd.read_csv('data/my_gls.csv')
df_known
# Out:
#              Name          ra      dec    n
# 0      J0011-0845    2.834350  -8.7643  2.0
# 1      J0013+5119    3.348077  51.3183  2.0
# 2    PSJ0028+0631    7.093690   6.5317  2.0
# 3    PSJ0030-1525    7.563600 -15.4177  4.0
# 4      J0047+2514   11.946594  25.2411  2.0
# ..            ...         ...      ...  ...
# 299    J2147-1340  326.995700 -13.6772  NaN
# 300    J2205+1019  331.416100  10.3307  NaN
# 301    J2213-5926  333.336300 -59.4376  NaN
# 302    J2308+3201  347.077700  32.0294  NaN
# 303    J2316+0610  349.133500   6.1804  NaN
#
# [304 rows x 4 columns]
